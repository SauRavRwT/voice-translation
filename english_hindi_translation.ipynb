# %% [markdown]
# # English-Hindi Text Translation

# %%
# !pip install googletrans==4.0.0-rc1

# %%
# Function to translate text
def translate_text():
    # Ask user for input
    text = input("Enter the text you want to translate: ")

    # Ask user for the translation direction
    direction = input("Translate to Hindi or English? (Enter 'hi' for Hindi, 'en' for English): ").strip().lower()

    # Perform translation based on user input
    if direction == 'hi':
        translated = translator.translate(text, src='en', dest='hi').text
        print(f"Translation to Hindi: {translated}")
    elif direction == 'en':
        translated = translator.translate(text, src='hi', dest='en').text
        print(f"Translation to English: {translated}")
    else:
        print("Invalid option. Please enter 'hi' for Hindi or 'en' for English.")

# Run the function
translate_text()
# Out:
# Translation to English: How are Nepali?
